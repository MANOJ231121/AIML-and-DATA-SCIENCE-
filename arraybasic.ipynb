# %%
# importing numpy
import numpy as np
a = np.arange(1,31).reshape(6,5)
a
slice = a[2:,1:3]
slice
# Out:
# array([[12, 13],
#        [17, 18],
#        [22, 23],
#        [27, 28]])

# %% [raw]
# this is the comment box here  and above example shows the example of slicing

# %%
import numpy as np
arr1 = np.array([[1,2,3],[2,3,4],[2,3,4]])
arr2 =np.array([[1,2,4],[2,3,9],[2,8,4]])
arr1 @ arr2
# Out:
# array([[11, 32, 34],
#        [16, 45, 51],
#        [16, 45, 51]])

# %%
import numpy as np

# %%
a = np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
import numpy as np
data = np.array([
    [18,85,78],
    [19,92,88],
    [17,76,95],
    [18,65,70],
    [20,90,85]])

# %%
#get the shape of the matrix
data.shape
# Out:
# (5, 3)

# %%
np.mean(data[:,0])
# Out:
# np.float64(18.4)

# %%
c = np.array(data[:,1])
c
# Out:
# array([85, 92, 76, 65, 90])

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1], 
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
f = np.sum(s,axis=0)
for i in f:
    if( i != 45):
        print("not valid")
        break
else:
    print("valid")
# Out:
# valid

# %%
h = np.sum(s,axis =1)
h
# Out:
# array([45, 45, 45, 45, 45, 45, 45, 45, 45])

# %%
m = s[ :3, :3]
m
# Out:
# array([[5, 3, 4],
#        [6, 7, 2],
#        [1, 9, 8]])

# %%
print(m.sum())
# Out:
# 45

# %%
for i in range (0,9,3):
    for j in range(0,9,3):
        n = (s[i:i+3,j:j+3])
        print(n.sum())
# Out:
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45
# 45

# %%
import numpy as np
data = np.array([
    [18,85,78],
    [19,92,88],
    [17,76,95],
    [18,65,70],
    [20,90,85]])

# %%
n = data[:,1]
n
# Out:
# array([85, 92, 76, 65, 90])

# %%
n = np.mean(n)

# %%
n
# Out:
# np.float64(81.6)

# %%
s = np.mean(data[:,2])
s
# Out:
# np.float64(83.2)

# %%
np.mean(data[:,1 :],axis =0)
# Out:
# array([81.6, 83.2])

# %%
# q = data[data[:,1]>=80]
# q
# q = data[data[:,1]>=80] and data[data[:,2]>=80]
# q
q = data[(data[:,1]>=80) & (data[:,2]>=80)]
q
# Out:
# array([[19, 92, 88],
#        [20, 90, 85]])

# %%
data[:,2][data[:,2]<75] =0
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65,  0],
#        [20, 90, 85]])
